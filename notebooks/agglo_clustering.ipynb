# %%
# %matplotlib inline
# %config Completer.use_jedi = False
# %load_ext autoreload
# %autoreload 2


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


pd.set_option('display.max_columns', 100)
pd.set_option('display.max_row', 500)
pd.set_option('display.max_colwidth', 200)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from pyrisk.binning import simple_bins, agglomerative_clustering_binning

# %%
def log_function(x):
    return 1/(1+np.exp(-10*x))

x = [log_function(x) for x in np.arange(-1,1,0.01)]

plt.plot(x);

# %% [markdown]
# Simple binning

# %%
counts, boundaries = simple_bins(x, bin_count=2)

# %%
df = pd.DataFrame({'x':x})
df['label'] = pd.cut(x, bins=boundaries, include_lowest=True)

fig, ax = plt.subplots()
for label in df.label.unique():
    df[df.label==label].plot(ax=ax, y='x', legend=False)

# %% [markdown]
# agglomerative_clustering_binning

# %%
counts, boundaries = agglomerative_clustering_binning(x, 4)
print('counts', counts)
print('boundaries', boundaries)
# Out:
# counts [24 16 80 80]
# boundaries [4.5397868702434395e-05, 0.11414987160886594, 0.5865650884620577, 0.8753443018074434, 0.9999498278353162]

# %%
df = pd.DataFrame({'x':x})
df['label'] = pd.cut(x, bins=boundaries, include_lowest=True)

fig, ax = plt.subplots()
for label in df.label.unique():
    df[df.label==label].plot(ax=ax, y='x', legend=False)
